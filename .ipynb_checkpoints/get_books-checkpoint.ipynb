# %%
import pandas as pd
from goodreads import client

# %%
books = pd.read_csv('good_books_10k/good_books_long.csv')

# %%
goodreads_key = 't6mIkabukH29jAey0381yA'
goodreads_secret = '6IWvvO5CNFIAqUragee2Bb5HkEOvxIYqSXeXdFSHvM'
good_client = client.GoodreadsClient(goodreads_key, goodreads_secret)

# %%
import time
good_descriptions = []
i = 1
for book_id in books['goodreads_book_id']:
    try:
        print(i)
        i += 1
        book = good_client.book(book_id)
        good_descriptions.append(book.description)
        time.sleep(0.5)
    except:
        pass

# %%
books['description'] = pd.Series(good_descriptions)

# %%
books.head()
# Out:
#    goodreads_book_id  ...                                        description
# 0            2767052  ...  Could you survive on your own, in the wild, wi...
# 1                  3  ...  Harry Potter's life is miserable. His parents ...
# 2              41865  ...  <b>About three things I was absolutely positiv...
# 3               2657  ...  The unforgettable novel of a childhood in a sl...
# 4               4671  ...  Alternate Cover Edition ISBN: 0743273567 (ISBN...
#
# [5 rows x 11 columns]

# %%
# function to remove the 'Alternate Cover Edition ...' paragraph at the beginning 
def clean_cover_isbn(text):
  try:
    text = text.split('<br />')[2]
    return text
  except:
    return text

# %%
# function to remove html markings
from bs4 import BeautifulSoup
def clean_html(text):
  try:
    soup = BeautifulSoup(text, 'lxml')
    clean_text = soup.get_text()
    return clean_text
  except:
    return text

# %%
# function to remove punctuation
import string
def clean_punctuations(text):
  clean_text = "".join([c for c in text if c not in string.punctuation])
  return clean_text

# %%
retrieve_books = books[books['description'].isnull()]
retrieve_books.reset_index(drop = True, inplace = True)

# %%
retrieve_books.shape
# Out:
# (125, 11)

# %%
import time
retrieve_good_descriptions = []
i = 1
for book_id in retrieve_books['goodreads_book_id']:
    try:
        print(i)
        i += 1
        book = good_client.book(book_id)
        retrieve_good_descriptions.append(book.description)
        time.sleep(0.5)
    except:
        pass

# %%
retrieve_good_descriptions

# %%
retrieve_books['description'] = pd.Series(retrieve_good_descriptions)

# %%
retrieve_books[:22]

# %%
retrieve_books = retrieve_books[~retrieve_books['description'].isnull()]

# %%
books.head()
# Out:
#    goodreads_book_id  ...                                        description
# 0            2767052  ...  Could you survive on your own, in the wild, wi...
# 1                  3  ...  Harry Potter's life is miserable. His parents ...
# 2              41865  ...  <b>About three things I was absolutely positiv...
# 3               2657  ...  The unforgettable novel of a childhood in a sl...
# 4               4671  ...  Alternate Cover Edition ISBN: 0743273567 (ISBN...
#
# [5 rows x 11 columns]

# %%
info_books = books[~books['description'].isnull()]

# %%
info_books = pd.concat([info_books, retrieve_books])

# %%
info_books.shape
# Out:
# (9979, 11)

# %%
info_books['description'] = info_books['description'].apply(lambda x: clean_cover_isbn(x))
info_books['description'] = info_books['description'].apply(lambda x: clean_html(x))
info_books['description'] = info_books['description'].apply(lambda x: clean_punctuations(x))

# %%
info_books.head()
# Out:
#    goodreads_book_id  ...                                        description
# 0            2767052  ...  In the ruins of a place once known as North Am...
# 1                  3  ...  After a lifetime of bottling up his magical po...
# 2              41865  ...                         First Edward was a vampire
# 3               2657  ...  Compassionate dramatic and deeply moving To Ki...
# 4               4671  ...  The Great Gatsby F Scott Fitzgeralds third boo...
#
# [5 rows x 11 columns]

# %%
from keras.preprocessing.text import text_to_word_sequence
def get_tokens(text):
  return text_to_word_sequence(text)
# Out:
# Using TensorFlow backend.

# %%
info_books['description'] = info_books['description'].apply(lambda x: get_tokens(x))

# %%
info_books = info_books[info_books['description'].map(lambda x: len(x) > 0)]

# %%
import pandas as pd
info_books = pd.read_csv('good_books_tokenized.csv')

# %%
info_books.head()
# Out:
#    goodreads_book_id  ... cluster
# 0            2767052  ...     3.0
# 1                  3  ...     3.0
# 2              41865  ...     9.0
# 3               2657  ...     5.0
# 4               4671  ...     7.0
#
# [5 rows x 13 columns]

# %%
from gensim.models.fasttext import FastText

# %%
model = FastText(min_count = 1)
model.build_vocab(sentences = list(info_books['description']))
model.train(sentences = list(info_books['description']), total_examples = len(list(info_books['description'])), epochs = 10, alpha = 0.01)

# %%
import numpy as np
def get_vector(df):
  description = np.array([model.wv[word] for word in df['description']]).mean(axis = 0)
  description_and_rating = np.append(description, df['average_rating']/5)
  return description_and_rating

# %%
info_books['vector_description'] = info_books.apply(get_vector, axis = 1)

# %%
info_books.head()
# Out:
#    goodreads_book_id  ... cluster
# 0            2767052  ...     3.0
# 1                  3  ...     3.0
# 2              41865  ...     9.0
# 3               2657  ...     5.0
# 4               4671  ...     7.0
#
# [5 rows x 13 columns]

# %%
X = list(info_books['vector_description'])
X = np.array(X)
X.shape
# Out:
# (9622, 101)

# %%
from sklearn.cluster import KMeans
n_clusters = [2, 5, 10, 15, 20]
inertia = []
for n in n_clusters:
  book_kmeans = KMeans(n_clusters = n)
  book_kmeans.fit(X)
  inertia.append(book_kmeans.inertia_)

# %%
import matplotlib.pyplot as plt
plt.plot(n_clusters, inertia)

# %%
# Seems like 10 clusters is the best

# %%
book_kmeans = KMeans(n_clusters = 200).fit(X)
book_kmeans.labels_
# Out:
# array([143, 165, 183, ...,  31,  64, 103], dtype=int32)

# %%
info_books['cluster'] = pd.Series(book_kmeans.labels_)

# %%
info_books[info_books['cluster'] == 101]
# Out:
#       goodreads_book_id  ... cluster
# 41                10210  ...     101
# 45                19063  ...     101
# 57                24178  ...     101
# 105                3473  ...     101
# 147                4989  ...     101
# 173              252577  ...     101
# 247                1232  ...     101
# 300             2213661  ...     101
# 309               10365  ...     101
# 393                9375  ...     101
# 462               43889  ...     101
# 473                7967  ...     101
# 499               34268  ...     101
# 596              402045  ...     101
# 639                2744  ...     101
# 677                4687  ...     101
# 768                7770  ...     101
# 772              271199  ...     101
# 899               18116  ...     101
# 911               13895  ...     101
# 912            20820994  ...     101
# 1017             227651  ...     101
# 1194            1848444  ...     101
# 1197              60400  ...     101
# 1326            7823678  ...     101
# 1389              38501  ...     101
# 1416            1240662  ...     101
# 1537            8949352  ...     101
# 1616             114159  ...     101
# 1621             189802  ...     101
# ...                 ...  ...     ...
# 6855             537094  ...     101
# 6867           23355069  ...     101
# 7020              28482  ...     101
# 7092           11595276  ...     101
# 7172              18878  ...     101
# 7282             132626  ...     101
# 7333             184644  ...     101
# 7428           12846479  ...     101
# 7438              37303  ...     101
# 7523             290039  ...     101
# 7578           19090384  ...     101
# 7596           12027429  ...     101
# 7789             103111  ...     101
# 7841             419103  ...     101
# 7869            1233478  ...     101
# 8015            8074967  ...     101
# 8131             270032  ...     101
# 8134            8158992  ...     101
# 8220              62032  ...     101
# 8367           25772000  ...     101
# 8435             428223  ...     101
# 8475             925367  ...     101
# 8623             975119  ...     101
# 8697             900070  ...     101
# 8701            9065265  ...     101
# 9229           12389310  ...     101
# 9248           25067046  ...     101
# 9401              88442  ...     101
# 9412           10165727  ...     101
# 9588             153783  ...     101
#
# [128 rows x 13 columns]

# %%
info_books.to_csv('good_books_tokenized.csv', index = False)

# %%
from google.colab import files

files.download('good_books_tokenized.csv')

# %%
# unsupervised first
# cluster first then assign label from labelled data points to entire cluster
# train supervised models
